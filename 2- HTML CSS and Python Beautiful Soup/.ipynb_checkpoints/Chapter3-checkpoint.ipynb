# %%
import requests
url = 'https://en.wikipedia.org/w/index.php' + \
      '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of Game of Thrones episodes - Wikipedia</title>
# ...

# %%
# !pip install -U beautifulsoup4
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the 'c:\users\administrator\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/w/index.php' + \
      '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_contents = r.text
html_soup = BeautifulSoup(html_contents)

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of Game of Thrones episodes - Wikipedia</title>
# ...

# %%
print(html_soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Game of Thrones episodes - Wikipedia</title>
# ...

# %%
print(html_contents)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of Game of Thrones episodes - Wikipedia</title>
# ...

# %% [markdown]
# passing html parser as argument

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/w/index.php' + \
      '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_contents = r.text
html_soup = BeautifulSoup(html_contents, 'html.parser')
print(r)
# Out:
# <Response [200]>

# %% [markdown]
# we can target the html tags accoring to the tag names given as list in find_all method of beautifulsoup

# %%
# print(html_soup.find(['h2','h1']))
# print(html_soup.find('', {'id': 'p-logo'}))
for found in html_soup.find_all(['h3', 'h1']):
    print(found)
# Out:
# <h1 class="firstHeading" id="firstHeading">List of <i>Game of Thrones</i> episodes</h1>
# <h3><span id="Season_1_.282011.29"></span><span class="mw-headline" id="Season_1_(2011)">Season 1 (2011)</span></h3>
# <h3><span id="Season_2_.282012.29"></span><span class="mw-headline" id="Season_2_(2012)">Season 2 (2012)</span></h3>
# <h3><span id="Season_3_.282013.29"></span><span class="mw-headline" id="Season_3_(2013)">Season 3 (2013)</span></h3>
# <h3><span id="Season_4_.282014.29"></span><span class="mw-headline" id="Season_4_(2014)">Season 4 (2014)</span></h3>
# <h3><span id="Season_5_.282015.29"></span><span class="mw-headline" id="Season_5_(2015)">Season 5 (2015)</span></h3>
# <h3><span id="Season_6_.282016.29"></span><span class="mw-headline" id="Season_6_(2016)">Season 6 (2016)</span></h3>
# <h3><span id="Season_7_.282017.29"></span><span class="mw-headline" id="Season_7_(2017)">Season 7 (2017)</span></h3>
# <h3 class="vector-menu-heading" id="p-personal-label">
# ...

# %% [markdown]
# we can also target the children of elements like below

# %%
for found in html_soup.find_all(['h3', 'h1']):
    print(found.find('span'))
# Out:
# None
# <span id="Season_1_.282011.29"></span>
# <span id="Season_2_.282012.29"></span>
# <span id="Season_3_.282013.29"></span>
# <span id="Season_4_.282014.29"></span>
# <span id="Season_5_.282015.29"></span>
# <span id="Season_6_.282016.29"></span>
# <span id="Season_7_.282017.29"></span>
# <span>Personal tools</span>
# <span>Namespaces</span>
# <span>Variants</span>
# <span>Views</span>
# <span>More</span>
# None
# <span>Navigation</span>
# <span>Contribute</span>
# <span>Tools</span>
# <span>Print/export</span>
# <span>In other projects</span>
# <span>Languages</span>

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/w/index.php' + \
      '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_contents = r.text
html_soup = BeautifulSoup(html_contents, 'html.parser')
# Find the first h1 tag
first_h1 = html_soup.find('h1')
print(first_h1.name)     # h1
print(first_h1.contents) # ['List of ', [...], ' episodes']
print(str(first_h1))
# Prints out: <h1 class="firstHeading" id="firstHeading" lang="en">List of
#             <i>Game of Thrones</i> episodes</h1>
print(first_h1.text)       # List of Game of Thrones episodes
print(first_h1.get_text()) # Does the same
print(first_h1.attrs)
# Prints out: {'id': 'firstHeading', 'class': ['firstHeading'], 'lang': 'en'}
print(first_h1.attrs['id']) # firstHeading
print(first_h1['id'])       # Does the same
print(first_h1.get('id'))   # Does the same
print('------------ CITATIONS ------------')
# Find the first five cite elements with a citation class
cites = html_soup.find_all('cite', class_='citation')
print("this is  the lenght EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE",type(cites), len(cites))
for citation in cites:
    print(citation.get_text())
    # Inside of this cite element, find the first a tag
    try:
        link = citation.find_all('a')
        print(' this is the type of thelink',type(link))
        # ... and show its URL
        #if there is no link in the <a> tag then it will ruturn None type , we can cater for this
        #try except block
        for li in link:
            print(li.get('href'))
        print(" Two Links")
    except:
        print('no link found')
        continue
# Out:
# h1
# ['List of ', <i>Game of Thrones</i>, ' episodes']
# <h1 class="firstHeading" id="firstHeading">List of <i>Game of Thrones</i> episodes</h1>
# List of Game of Thrones episodes
# List of Game of Thrones episodes
# {'id': 'firstHeading', 'class': ['firstHeading']}
# firstHeading
# firstHeading
# firstHeading
# ------------ CITATIONS ------------
# this is  the lenght EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE <class 'bs4.element.ResultSet'> 108
# Fowler, Matt (April 8, 2011). "Game of Thrones: "Winter is Coming" Review". IGN. Archived from the original on August 17, 2012. Retrieved September 22, 2016.
#  this is the type of thelink <class 'bs4.element.ResultSet'>
# https://web.archive.org/web/20120817073932/http://tv.ign.com/articles/116/1160215p1.html
# /wiki/IGN
# http://tv.ign.com/articles/116/1160215p1.html
#  Two Links
# Fleming, Michael (January 16, 2007). "HBO turns Fire into fantasy series". Variety. Archived from the original on May 16, 2012. Retrieved September 3, 2016.
# ...

# %%
first_h11 = html_soup.find_all('h3')
print(first_h11)
# Out:
# [<h3><span id="Season_1_.282011.29"></span><span class="mw-headline" id="Season_1_(2011)">Season 1 (2011)</span></h3>, <h3><span id="Season_2_.282012.29"></span><span class="mw-headline" id="Season_2_(2012)">Season 2 (2012)</span></h3>, <h3><span id="Season_3_.282013.29"></span><span class="mw-headline" id="Season_3_(2013)">Season 3 (2013)</span></h3>, <h3><span id="Season_4_.282014.29"></span><span class="mw-headline" id="Season_4_(2014)">Season 4 (2014)</span></h3>, <h3><span id="Season_5_.282015.29"></span><span class="mw-headline" id="Season_5_(2015)">Season 5 (2015)</span></h3>, <h3><span id="Season_6_.282016.29"></span><span class="mw-headline" id="Season_6_(2016)">Season 6 (2016)</span></h3>, <h3><span id="Season_7_.282017.29"></span><span class="mw-headline" id="Season_7_(2017)">Season 7 (2017)</span></h3>, <h3 class="vector-menu-heading" id="p-personal-label">
# <span>Personal tools</span>
# </h3>, <h3 class="vector-menu-heading" id="p-namespaces-label">
# ...

# %%
for found in html_soup.find_all(['h3', 'h1']):
    for i in found.find_all('span'):
        try:
            print(i.get('id')) # if we use get here , then we will get None type
            print(i['id']) # this method will not print none , instead will throw error
            print(i)
        except:
            
            print( " No Element was found")
# Out:
# Season_1_.282011.29
# Season_1_.282011.29
# <span id="Season_1_.282011.29"></span>
# Season_1_(2011)
# Season_1_(2011)
# <span class="mw-headline" id="Season_1_(2011)">Season 1 (2011)</span>
# Season_2_.282012.29
# Season_2_.282012.29
# <span id="Season_2_.282012.29"></span>
# Season_2_(2012)
# Season_2_(2012)
# <span class="mw-headline" id="Season_2_(2012)">Season 2 (2012)</span>
# Season_3_.282013.29
# Season_3_.282013.29
# <span id="Season_3_.282013.29"></span>
# Season_3_(2013)
# Season_3_(2013)
# <span class="mw-headline" id="Season_3_(2013)">Season 3 (2013)</span>
# Season_4_.282014.29
# Season_4_.282014.29
# <span id="Season_4_.282014.29"></span>
# Season_4_(2014)
# Season_4_(2014)
# <span class="mw-headline" id="Season_4_(2014)">Season 4 (2014)</span>
# Season_5_.282015.29
# Season_5_.282015.29
# <span id="Season_5_.282015.29"></span>
# Season_5_(2015)
# Season_5_(2015)
# <span class="mw-headline" id="Season_5_(2015)">Season 5 (2015)</span>
# Season_6_.282016.29
# ...

# %%
for citation in cites:
    print(" TYPE OF CITATIONNNNNNNNNNNNNNNNNNNNNN",type(citation))
    print(citation.get_text())
    # Inside of this cite element, find the first a tag
#     try:
    link = citation('a')
#     print(' this is the type of thelink[0]',type(link[0]))
#     print(' this is the type of thelink',type(link))
    # ... and show its URL
    #if there is no link in the <a> tag then it will ruturn None type , we can cater for this
    #try except block
    #link is type of <class 'bs4.element.ResultSet'> which is iterable and does not have method 'get'
    for x in link:
        print(' the type of XXXXXX',type(x))
#         <class 'bs4.element.Tag'>  here 'x' is this type class which allows us to use get method to
# parse its child e.g href , title etc....
        print('experimentVVVVVVVVVVVVVVVVVVVVVVVVVVVVV', x.get('href'))
    print('jjjjjjjjjjjjjj', link.reverse)
#     print('HHHHHHHHHHHHHHHHHHHHHHH', x.get('href'))
#     print()
#     except:
#         print('no link found')
#         continue
# Out:
#  TYPE OF CITATIONNNNNNNNNNNNNNNNNNNNNN <class 'bs4.element.Tag'>
# Fowler, Matt (April 8, 2011). "Game of Thrones: "Winter is Coming" Review". IGN. Archived from the original on August 17, 2012. Retrieved September 22, 2016.
#  the type of XXXXXX <class 'bs4.element.Tag'>
# experimentVVVVVVVVVVVVVVVVVVVVVVVVVVVVV https://web.archive.org/web/20120817073932/http://tv.ign.com/articles/116/1160215p1.html
#  the type of XXXXXX <class 'bs4.element.Tag'>
# experimentVVVVVVVVVVVVVVVVVVVVVVVVVVVVV /wiki/IGN
#  the type of XXXXXX <class 'bs4.element.Tag'>
# experimentVVVVVVVVVVVVVVVVVVVVVVVVVVVVV http://tv.ign.com/articles/116/1160215p1.html
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x000001910BB29C20>
#  TYPE OF CITATIONNNNNNNNNNNNNNNNNNNNNN <class 'bs4.element.Tag'>
# Fleming, Michael (January 16, 2007). "HBO turns Fire into fantasy series". Variety. Archived from the original on May 16, 2012. Retrieved September 3, 2016.
# ...

# %%
for citation in cites:
#     print(citation.get_text())

    link = citation('a')
 
    print('jjjjjjjjjjjjjj', link.reverse)
# Out:
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x000002718311AD10>
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x00000271837EFD60>
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x000002718311AD10>
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x00000271837EFD60>
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x000002718311AD10>
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x00000271837EFD60>
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x000002718311AD10>
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x00000271837EFD60>
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x000002718311AD10>
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x00000271837EFD60>
# jjjjjjjjjjjjjj <built-in method reverse of ResultSet object at 0x000002718311AD10>
# ...

# %% [markdown]
# ### Fetching table data from Wikipedia

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/w/index.php' + \
      '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_contents = r.text
html_soup = BeautifulSoup(html_contents, 'html.parser')
# We'll use a list to store our episode list
episodes = []
# here we are using class_ variable because python has built-in keword for "class" which will 
#  be ambigous with HTML class keyword
ep_tables = html_soup.find_all('table', class_='wikitable plainrowheaders wikiepisodetable')
print(" TableeeeeeeeeeeeeeeeeeeVVVVVVVVVeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee", len(ep_tables))
# Out:
#  TableeeeeeeeeeeeeeeeeeeVVVVVVVVVeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee 7

# %%
for table in ep_tables:
    headers = []
    
#     rows = table.find_all('tr')
#     print( "TYPEEEEEEEEEEEEEEEEEEEEEEEE of ROWWWS", type(rows), len(rows))
     # Start by fetching the header cells from the first row to determine
     # the field names
    for header in table.find('tr').find_all('th'):
#         print(header.text)
        headers.append(header.text)
    #print("headers list", headers[0
    #Then go through all the rows except the first one
    for row in table.find_all('tr')[1:]:
        values = []
        # And get the column cells, the first one being inside a th-tag
        for col in row.find_all(['th','td']):
            values.append(col.text)
        print(values)
        if values:
            episode_dict = {headers[i]: values[i] for i in range(len(values))}
            episodes.append(episode_dict)
# Show the results
# print("Number of EPISDIES", len(episodes))
for episode in episodes:
    print(episode)
# Out:
# ['1', '1', '"Winter Is Coming"', 'Tim Van Patten', 'David Benioff & D. B. Weiss', 'April\xa017,\xa02011\xa0(2011-04-17)', '2.22[21]']
# ['2', '2', '"The Kingsroad"', 'Tim Van Patten', 'David Benioff & D. B. Weiss', 'April\xa024,\xa02011\xa0(2011-04-24)', '2.20[22]']
# ['3', '3', '"Lord Snow"', 'Brian Kirk', 'David Benioff & D. B. Weiss', 'May\xa01,\xa02011\xa0(2011-05-01)', '2.44[23]']
# ['4', '4', '"Cripples, Bastards, and Broken Things"', 'Brian Kirk', 'Bryan Cogman', 'May\xa08,\xa02011\xa0(2011-05-08)', '2.45[24]']
# ['5', '5', '"The Wolf and the Lion"', 'Brian Kirk', 'David Benioff & D. B. Weiss', 'May\xa015,\xa02011\xa0(2011-05-15)', '2.58[25]']
# ['6', '6', '"A Golden Crown"', 'Daniel Minahan', 'Story by\u200a: David Benioff & D. B. WeissTeleplay by\u200a: Jane Espenson and David Benioff & D. B. Weiss', 'May\xa022,\xa02011\xa0(2011-05-22)', '2.44[26]']
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/w/index.php' + \
      '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_contents = r.text
html_soup = BeautifulSoup(html_contents, 'html.parser')
# We'll use a list to store our episode list

# %%
episodes = []
ep_tables = html_soup.find_all('table', class_='wikiepisodetable')
for table in ep_tables:
    headers = []
    rows = table.find_all('tr')
     # Start by fetching the header cells from the first row to determine
     # the field names
    for header in table.find('tr').find_all('th'):
        headers.append(header.text)
    # Then go through all the rows except the first one
    for row in table.find_all('tr')[1:]:
        values = []
        # And get the column cells, the first one being inside a th-tag
        for col in row.find_all(['th','td']):
            values.append(col.text)
        print("lenght of rows : " , len(values))
        print("lenght of haders : " , len(headers))
            
        if values:
            episode_dict = {headers[i]: values[i] for i in range(len(values))}
            episodes.append(episode_dict)
# Show the results
print("The length of episodes", len(episodes))
for episode in episodes:
    print(episode)
# Out:
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# lenght of haders :  7
# lenght of rows :  7
# ...

# %%
for i,j in enumerate(row.find_all(['th','td'])):
    print("index  :{}, elementn: {} ".format(i,j) )
# Out:
# index  :0, elementn: <th id="ep67" rowspan="1" scope="row" style="text-align:center">67</th>
# index  :1, elementn: <td style="text-align:center">7</td>
# index  :2, elementn: <td class="summary" style="text-align:left">"<a href="/wiki/The_Dragon_and_the_Wolf" title="The Dragon and the Wolf">The Dragon and the Wolf</a>"</td>
# index  :3, elementn: <td style="text-align:center">Jeremy Podeswa</td>
# index  :4, elementn: <td style="text-align:center">David Benioff &amp; D. B. Weiss</td>
# index  :5, elementn: <td style="text-align:center">August 27, 2017<span style="display:none"> (<span class="bday dtstart published updated">2017-08-27</span>)</span></td>
# index  :6, elementn: <td style="text-align:center">12.07<sup class="reference" id="cite_ref-s07e07_87-0"><a href="#cite_note-s07e07-87">[87]</a></sup></td>

# %%
for i,j in enumerate(row.find_all(['td'])):
    print("index  :{}, elementn: {} ".format(i,j) )
# Out:
# index  :0, elementn: <td style="text-align:center">7</td>
# index  :1, elementn: <td class="summary" style="text-align:left">"<a href="/wiki/The_Dragon_and_the_Wolf" title="The Dragon and the Wolf">The Dragon and the Wolf</a>"</td>
# index  :2, elementn: <td style="text-align:center">Jeremy Podeswa</td>
# index  :3, elementn: <td style="text-align:center">David Benioff &amp; D. B. Weiss</td>
# index  :4, elementn: <td style="text-align:center">August 27, 2017<span style="display:none"> (<span class="bday dtstart published updated">2017-08-27</span>)</span></td>
# index  :5, elementn: <td style="text-align:center">12.07<sup class="reference" id="cite_ref-s07e07_87-0"><a href="#cite_note-s07e07-87">[87]</a></sup></td>

# %% [markdown]
# # Extracting pictures and concatenate URL

# %%
episodes = []
image = []
pic_link = html_soup.find_all('img')
print(type(pic_link[0]))
for p in pic_link:
    x = p.get('src')
#     print(" THE SHORT SOURCEEEEEEEEEEE LINK", x)
#     if URL is not complete in the src , then you need to take the src srting and concatenate
# with Home URL, then you will be able to parse the URL of image correctly
# url = 'https://en.wikipedia.org/w/index.php' + \
#       '?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
    m = url.split("/") 
#     print(" SPLitted URL", m)
    if x[0:2] != "//":
        x = m[0] + '//' + m[2] + x
    elif x[0:2] == '//':
        x = m[0]+'//'+m[2] +'/'+ x[2:]
#     print('the source of Image is :', x)
    r = requests.get(x)
    print(r.content)
    image.append(r.content)
# Out:
# <class 'bs4.element.Tag'>
# ...

# %%
x = url.split("/")
print(x)
# Out:
# ['https:', '', 'en.wikipedia.org', 'w', 'index.php?title=List_of_Game_of_Thrones_episodes&oldid=802553687']

# %%
image
# Out:
# [b'<!DOCTYPE html>\n<html lang="en" dir="ltr">\n<meta charset="utf-8">\n<title>Not Found</title>\n<link rel="shortcut icon" href="/favicon.ico">\n<style>\n* { margin: 0; padding: 0; }\nbody { background: #fff; color: #202122; font: 0.938em/1.6 sans-serif; }\n.content { margin: 7% auto 0; padding: 2em 1em 1em; max-width: 640px; }\nimg { float: left; margin: 0 2em 2em 0; }\na img { border: 0; }\nh1 { margin-top: 1em; font-size: 1.2em; }\np { margin: 0.7em 0 1em 0; }\na { color: #36c; text-decoration: none; }\na:hover { text-decoration: underline; }\nem { color: #72777d; font-style: normal; }\n</style>\n<div class="content" role="main">\n<a href="https://www.wikimedia.org"><img src="https://www.wikimedia.org/static/images/wmf.png" srcset="https://www.wikimedia.org/static/images/wmf-2x.png 2x" alt=Wikimedia width=135 height=135></a>\n<h1>Page not found</h1>\n<p><em>/upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png</em></p>\n<p>We could not find th
# ...

# %%
from PIL import Image
import io
image_bytes = image[4]
Image.open(io.BytesIO(image_bytes))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-76-908f756251d1> in <module>
#       2 import io
#       3 image_bytes = image[4]
# ----> 4 Image.open(io.BytesIO(image_bytes))
#
# c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2941     for message in accept_warnings:
#    2942         warnings.warn(message)
# -> 2943     raise UnidentifiedImageError(
#    2944         "cannot identify image file %r" % (filename if filename else fp)
#    2945     )
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x000001910BF7F9A0>

# %% [markdown]
# ## using CSS selectors in beautiful soup

# %%
# # Find all <a> tags
# print(html_soup.select('a'))
# # Find the element with the info id
# print(html_soup.select('#info'))
# Find <div> tags with both classa and classb CSS classes
print(html_soup.select('div.after-portlet.after-portlet-lang'))
# Out:
# [<div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q847578#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>]

# %%
# Find <a> tags with an href attribute starting with http://example.com/
# print(html_soup.select('a[href^="http://example.com/"]'))
# Find <li> tags which are children of <ul> tags with class lst
html_soup.select('ul > li')
# Out:
# [<li class="toclevel-1 tocsection-1"><a href="#Series_overview"><span class="tocnumber">1</span> <span class="toctext">Series overview</span></a></li>,
#  <li class="toclevel-1 tocsection-2"><a href="#Episodes"><span class="tocnumber">2</span> <span class="toctext">Episodes</span></a>
#  <ul>
#  <li class="toclevel-2 tocsection-3"><a href="#Season_1_(2011)"><span class="tocnumber">2.1</span> <span class="toctext">Season 1 (2011)</span></a></li>
#  <li class="toclevel-2 tocsection-4"><a href="#Season_2_(2012)"><span class="tocnumber">2.2</span> <span class="toctext">Season 2 (2012)</span></a></li>
#  <li class="toclevel-2 tocsection-5"><a href="#Season_3_(2013)"><span class="tocnumber">2.3</span> <span class="toctext">Season 3 (2013)</span></a></li>
#  <li class="toclevel-2 tocsection-6"><a href="#Season_4_(2014)"><span class="tocnumber">2.4</span> <span class="toctext">Season 4 (2014)</span></a></li>
# ...

# %%
for link in html_soup.select('ol.references cite a[href]'):
    print(link)
# Out:
# vlaue of I : 0 <a class="external text" href="https://web.archive.org/web/20120817073932/http://tv.ign.com/articles/116/1160215p1.html" rel="nofollow">"Game of Thrones: "Winter is Coming" Review"</a>
# vlaue of I : 1 <a href="/wiki/IGN" title="IGN">IGN</a>
# vlaue of I : 2 <a class="external text" href="http://tv.ign.com/articles/116/1160215p1.html" rel="nofollow">the original</a>
# vlaue of I : 3 <a class="external text" href="https://web.archive.org/web/20120516224747/http://www.variety.com/article/VR1117957532?refCatId=14" rel="nofollow">"HBO turns <i>Fire</i> into fantasy series"</a>
# vlaue of I : 4 <a href="/wiki/Variety_(magazine)" title="Variety (magazine)">Variety</a>
# vlaue of I : 5 <a class="external text" href="http://www.variety.com/article/VR1117957532.html?categoryid=14&amp;cs=1" rel="nofollow">the original</a>
# vlaue of I : 6 <a class="external text" href="http://www.emmys.com/shows/game-thrones" rel="nofollow">"Game of Thrones"</a>
# ...
